# %% [markdown]
# ### **Loading Markdown files(.md)**

# %%
from langchain_community.document_loaders import UnstructuredMarkdownLoader

# %%
loader=UnstructuredMarkdownLoader("demo.md")
Markdown_content=loader.load()

# %%
print(Markdown_content[0])
# Out:
# page_content='Rajesh Hamal
#
# Overview
#
# Rajesh Hamal is a legendary Nepali actor, environmental activist, and producer, widely regarded as one of the most influential and successful actors in the history of Nepali cinema. Often referred to as the "Maha Nayak" (Great Hero) of Nepal, he has dominated the Nepali film industry for over three decades.
#
# Personal Information
#
# Full Name: Rajesh Hamal
#
# Date of Birth: June 9, 1964
#
# Age: 61 years (as of 2025)
#
# Place of Birth: Tansen, Palpa, Nepal
#
# Nationality: Nepali
#
# Occupation: Actor, Producer, Environmental Activist
#
# Years Active: 1991 - Present
#
# Spouse: Madhu Bhattarai (married in 2014)
#
# Early Life and Education
#
# Rajesh Hamal was born in Tansen, Palpa, Nepal to Dr. Hari Prasad Hamal and Droupadi Hamal. His father was a prominent physician and his mother was a housewife. He spent much of his childhood in Moscow, Russia, where his father was studying medicine.
#
# Education
#
# ...

# %% [markdown]
# ### **LOADINT THE PYTHON FILES**

# %% [markdown]
# ```
# from langchain_community.documnet_loaders import PythonLoader
# loader=PythonLoader('chatbot.py')
# python_data=loader.load()
# print(python_data[0])
# ```
# ----------
# **Splitting code files**
# ```
# python_splitter=RecursiveCharacterSplitter(
#     chunk_size=150,chunk_overlap=10
# )
# chunks=python_splitter.split_documents(pythoh_data)
# for i,chunk in enumerate(chunks[:3]):
#     print(f"Chunk {i+1}:\n{chunk.page_content}\n")
# ```
# -------------------
# **Splitting by language**
# ```
# from langchain_text_splitters import RecursiveCharacterSplitter, Language
# python_splitter=RecursiveCharacterSplitter.from_language(language=Language.PYTHON,chunk_size=150,chunk_overlap=10)
# chunks=python_splitter.split_documents(data)
# ```
